# %% [markdown]
# # Empowering Healthcare with Symbolic Learning and Knowledge Graph Embeddings

# %% [markdown]
# ![Desing Pattern](https://github.com/SDM-TIB/HyAI/assets/25593410/42cf771d-b82d-4097-b0f7-0ceb3581b171)

# %% [markdown]
# ## **Pattern Detection, Analysis and Explanation over P4-LUCAT Knowledge Graph**
#
# > Unsupervised learning
# *   Save Learned Embeddings
# *   Apply cluster Algorithm: KMeans
# *   Select the optimal number of clusters
# *   Visualize PCA Projection to 2D

# %% [markdown]
# Git clone

# %%
# !git clone https://github.com/SDM-TIB/SymbolicLearning_KGE.git
# %cd SymbolicLearning_KGE/PatternDetection

# %%
import ComputeCommunities as SemCD

# %% [markdown]
# **Clean the build**

# %%
# !make clean

# %% [markdown]
# **Build the project**

# %%
# !make

# %% [markdown]
# ### Run the semEP-node

# %% [markdown]
# **Parameter input**

# %%
model_list = ['TransH', 'RotatE']
threshold = [30, 40, 50, 60, 70, 80]
kg_name = 'OriginalKG'
target_predicate = 'hasRelapse_Progression'

# %%
SemCD.run(kg_name=kg_name, target_predicate=target_predicate,
          model_list=model_list, threshold=threshold)
# Out:
# percentil 0.5388197128538618
#
# **********************************************
# Parameters:
# Nodes file name: clusteringMeasures/TransH/ClinicalRecord.txt
# Matrix file name: clusteringMeasures/TransH/matrix_ClinicalRecord.tsv
# Threshold: 0.539
# ************************************************
#
# **** GO semEP-Node! ****
# Proccessing the vertex file clusteringMeasures/TransH/ClinicalRecord.txt ...
# Number of nodes of the input file: 1242
# Time to build the graph to coloring: 0.0128 secs
# Graph to coloring - Num. of Nodes: 1242; Num. of Edges: 0
# Start coloring
# Average density of the partitions: 0.6620
# Number of partitions: 1
# Cluster directory: ClinicalRecord-0.5388-14h-38m-14s-Clusters
# Coloring solver time: 0.0062 secs
# Total time 0.245 secs
# /home/rivas/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# percentil 0.5913420431204749
#
# **********************************************
# Parameters:
# Nodes file name: clusteringMeasures/TransH/ClinicalRecord.txt
# Matrix file name: clusteringMeasures/TransH/matrix_ClinicalRecord.tsv
# Threshold: 0.591
# ************************************************
#
# **** GO semEP-Node! ****
# Proccessing the vertex file clusteringMeasures/TransH/ClinicalRecord.txt ...
# Number of nodes of the input file: 1242
# Time to build the graph to coloring: 0.0462 secs
# Graph to coloring - Num. of Nodes: 1242; Num. of Edges: 3425
# Start coloring
# Average density of the partitions: 0.7598
# Number of partitions: 4
# Cluster directory: ClinicalRecord-0.5913-14h-38m-22s-Clusters
# Coloring solver time: 0.0091 secs
# Total time 0.275 secs
# ******************************************************************************
# METIS 5.0 Copyright 1998-13, Regents of the University of Minnesota
#  (HEAD: , Built on: May 17 2018, 14:13:21)
#  size of idx_t: 32bits, real_t: 32bits, idx_t *: 64bits
#
# Graph Information -----------------------------------------------------------
#  Name: metis.graph, #Vertices: 1242, #Edges: 770661, #Parts: 4
#
# Options ---------------------------------------------------------------------
#  ptype=kway, objtype=cut, ctype=shem, rtype=greedy, iptype=metisrb
#  dbglvl=0, ufactor=1.030, no2hop=NO, minconn=NO, contig=NO, nooutput=NO
#  seed=-1, niter=10, ncuts=1
#
# Direct k-way Partitioning ---------------------------------------------------
#  - Edgecut: -205289091, communication volume: 3726.
#
#  - Balance:
#      constraint #0:  1.027 out of 0.003
#
#  - Most overweight partition:
#      pid: 0, actual: 319, desired: 310, ratio: 1.03.
#
#  - Subdomain connectivity: max: 3, min: 1, avg: 1.50
#
#  - Each partition is contiguous.
#
# Timing Information ----------------------------------------------------------
#   I/O:          		   0.154 sec
#   Partitioning: 		   0.040 sec   (METIS time)
#   Reporting:    		   0.013 sec
#
# Memory Information ----------------------------------------------------------
#   Max memory used:		  16.887 MB
# ******************************************************************************
# /home/rivas/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# percentil 0.6489578214498659
#
# **********************************************
# Parameters:
# Nodes file name: clusteringMeasures/TransH/ClinicalRecord.txt
# Matrix file name: clusteringMeasures/TransH/matrix_ClinicalRecord.tsv
# Threshold: 0.649
# ************************************************
#
# **** GO semEP-Node! ****
# Proccessing the vertex file clusteringMeasures/TransH/ClinicalRecord.txt ...
# Number of nodes of the input file: 1242
# Time to build the graph to coloring: 0.2532 secs
# Graph to coloring - Num. of Nodes: 1242; Num. of Edges: 47211
# Start coloring
# Average density of the partitions: 0.7460
# Number of partitions: 20
# Cluster directory: ClinicalRecord-0.6490-14h-38m-40s-Clusters
# Coloring solver time: 0.0099 secs
# Total time 0.485 secs
# ******************************************************************************
# METIS 5.0 Copyright 1998-13, Regents of the University of Minnesota
#  (HEAD: , Built on: May 17 2018, 14:13:21)
#  size of idx_t: 32bits, real_t: 32bits, idx_t *: 64bits
#
# Graph Information -----------------------------------------------------------
#  Name: metis.graph, #Vertices: 1242, #Edges: 770661, #Parts: 20
#
# Options ---------------------------------------------------------------------
#  ptype=kway, objtype=cut, ctype=shem, rtype=greedy, iptype=metisrb
#  dbglvl=0, ufactor=1.030, no2hop=NO, minconn=NO, contig=NO, nooutput=NO
#  seed=-1, niter=10, ncuts=1
#
# Direct k-way Partitioning ---------------------------------------------------
#  - Edgecut: 676342766, communication volume: 23598.
#
#  - Balance:
#      constraint #0:  1.014 out of 0.016
#
#  - Most overweight partition:
#      pid: 0, actual: 63, desired: 62, ratio: 1.01.
#
#  - Subdomain connectivity: max: 19, min: 19, avg: 19.00
#
#  - Each partition is contiguous.
#
# Timing Information ----------------------------------------------------------
#   I/O:          		   0.149 sec
#   Partitioning: 		   0.110 sec   (METIS time)
#   Reporting:    		   0.010 sec
#
# Memory Information ----------------------------------------------------------
#   Max memory used:		  16.285 MB
# ******************************************************************************
# /home/rivas/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# percentil 0.7113416163925279
#
# **********************************************
# Parameters:
# Nodes file name: clusteringMeasures/TransH/ClinicalRecord.txt
# Matrix file name: clusteringMeasures/TransH/matrix_ClinicalRecord.tsv
# Threshold: 0.711
# ************************************************
#
# **** GO semEP-Node! ****
# Proccessing the vertex file clusteringMeasures/TransH/ClinicalRecord.txt ...
# Number of nodes of the input file: 1242
# Time to build the graph to coloring: 0.6050 secs
# Graph to coloring - Num. of Nodes: 1242; Num. of Edges: 158358
# Start coloring
# Average density of the partitions: 0.4256
# Number of partitions: 75
# Cluster directory: ClinicalRecord-0.7113-14h-38m-58s-Clusters
# Coloring solver time: 0.0136 secs
# Total time 0.839 secs
# ******************************************************************************
# METIS 5.0 Copyright 1998-13, Regents of the University of Minnesota
#  (HEAD: , Built on: May 17 2018, 14:13:21)
#  size of idx_t: 32bits, real_t: 32bits, idx_t *: 64bits
#
# Graph Information -----------------------------------------------------------
#  Name: metis.graph, #Vertices: 1242, #Edges: 770661, #Parts: 75
#
# Options ---------------------------------------------------------------------
#  ptype=kway, objtype=cut, ctype=shem, rtype=greedy, iptype=metisrb
#  dbglvl=0, ufactor=1.030, no2hop=NO, minconn=NO, contig=NO, nooutput=NO
#  seed=-1, niter=10, ncuts=1
#
# Direct k-way Partitioning ---------------------------------------------------
#  - Edgecut: 806940265, communication volume: 91908.
#
#  - Balance:
#      constraint #0:  1.027 out of 0.060
#
#  - Most overweight partition:
#      pid: 0, actual: 17, desired: 16, ratio: 1.03.
#
#  - Subdomain connectivity: max: 74, min: 74, avg: 74.00
#
#  - Each partition is contiguous.
#
# Timing Information ----------------------------------------------------------
#   I/O:          		   0.153 sec
#   Partitioning: 		   0.352 sec   (METIS time)
#   Reporting:    		   0.009 sec
#
# Memory Information ----------------------------------------------------------
#   Max memory used:		  35.429 MB
# ******************************************************************************
# /home/rivas/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# percentil 0.7773488365360885
#
# **********************************************
# Parameters:
# Nodes file name: clusteringMeasures/TransH/ClinicalRecord.txt
# Matrix file name: clusteringMeasures/TransH/matrix_ClinicalRecord.tsv
# Threshold: 0.777
# ************************************************
#
# **** GO semEP-Node! ****
# Proccessing the vertex file clusteringMeasures/TransH/ClinicalRecord.txt ...
# Number of nodes of the input file: 1242
# Time to build the graph to coloring: 0.8883 secs
# Graph to coloring - Num. of Nodes: 1242; Num. of Edges: 286978
# Start coloring
# Average density of the partitions: 0.2195
# Number of partitions: 173
# Cluster directory: ClinicalRecord-0.7773-14h-39m-17s-Clusters
# Coloring solver time: 0.0209 secs
# Total time 1.127 secs
# ******************************************************************************
# METIS 5.0 Copyright 1998-13, Regents of the University of Minnesota
#  (HEAD: , Built on: May 17 2018, 14:13:21)
#  size of idx_t: 32bits, real_t: 32bits, idx_t *: 64bits
#
# Graph Information -----------------------------------------------------------
#  Name: metis.graph, #Vertices: 1242, #Edges: 770661, #Parts: 173
#
# Options ---------------------------------------------------------------------
#  ptype=kway, objtype=cut, ctype=shem, rtype=greedy, iptype=metisrb
#  dbglvl=0, ufactor=1.030, no2hop=NO, minconn=NO, contig=NO, nooutput=NO
#  seed=-1, niter=10, ncuts=1
#
# Direct k-way Partitioning ---------------------------------------------------
#  - Edgecut: -825470075, communication volume: 213624.
#
#  - Balance:
#      constraint #0:  1.114 out of 0.139
#
#  - Most overweight partition:
#      pid: 1, actual: 8, desired: 7, ratio: 1.11.
#
#  - Subdomain connectivity: max: 172, min: 172, avg: 172.00
#
#  - Each partition is contiguous.
#
# Timing Information ----------------------------------------------------------
#   I/O:          		   0.158 sec
#   Partitioning: 		   0.874 sec   (METIS time)
#   Reporting:    		   0.010 sec
#
# Memory Information ----------------------------------------------------------
#   Max memory used:		  35.435 MB
# ******************************************************************************
# /home/rivas/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# percentil 0.8418229413795495
#
# **********************************************
# Parameters:
# Nodes file name: clusteringMeasures/TransH/ClinicalRecord.txt
# Matrix file name: clusteringMeasures/TransH/matrix_ClinicalRecord.tsv
# Threshold: 0.842
# ************************************************
#
# **** GO semEP-Node! ****
# Proccessing the vertex file clusteringMeasures/TransH/ClinicalRecord.txt ...
# Number of nodes of the input file: 1242
# Time to build the graph to coloring: 1.2450 secs
# Graph to coloring - Num. of Nodes: 1242; Num. of Edges: 405831
# Start coloring
# Average density of the partitions: 0.1442
# Number of partitions: 292
# Cluster directory: ClinicalRecord-0.8418-14h-39m-41s-Clusters
# Coloring solver time: 0.0288 secs
# Total time 1.511 secs
# ******************************************************************************
# METIS 5.0 Copyright 1998-13, Regents of the University of Minnesota
#  (HEAD: , Built on: May 17 2018, 14:13:21)
#  size of idx_t: 32bits, real_t: 32bits, idx_t *: 64bits
#
# Graph Information -----------------------------------------------------------
#  Name: metis.graph, #Vertices: 1242, #Edges: 770661, #Parts: 292
#
# Options ---------------------------------------------------------------------
#  ptype=kway, objtype=cut, ctype=shem, rtype=greedy, iptype=metisrb
#  dbglvl=0, ufactor=1.030, no2hop=NO, minconn=NO, contig=NO, nooutput=NO
#  seed=-1, niter=10, ncuts=1
#
# Direct k-way Partitioning ---------------------------------------------------
#  - Edgecut: -688446261, communication volume: 361422.
#
#  - Balance:
#      constraint #0:  1.176 out of 0.235
#
#  - Most overweight partition:
#      pid: 3, actual: 5, desired: 4, ratio: 1.18.
#
#  - Subdomain connectivity: max: 291, min: 291, avg: 291.00
#
#  - Each partition is contiguous.
#
# Timing Information ----------------------------------------------------------
#   I/O:          		   0.152 sec
#   Partitioning: 		   1.387 sec   (METIS time)
#   Reporting:    		   0.010 sec
#
# Memory Information ----------------------------------------------------------
#   Max memory used:		  35.441 MB
# ******************************************************************************
# /home/rivas/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /media/rivas/Data1/Projects/SymbolicLearning_KGE/PatternDetection/Utility.py:29: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=standard_similarity, x="similarity", shade=True, cut=0,
# percentil 0.500454358730794
#
# **********************************************
# Parameters:
# Nodes file name: clusteringMeasures/RotatE/ClinicalRecord.txt
# Matrix file name: clusteringMeasures/RotatE/matrix_ClinicalRecord.tsv
# Threshold: 0.500
# ************************************************
#
# **** GO semEP-Node! ****
# Proccessing the vertex file clusteringMeasures/RotatE/ClinicalRecord.txt ...
# Number of nodes of the input file: 1242
# Time to build the graph to coloring: 0.0085 secs
# Graph to coloring - Num. of Nodes: 1242; Num. of Edges: 0
# Start coloring
# Average density of the partitions: 0.5473
# Number of partitions: 1
# Cluster directory: ClinicalRecord-0.5005-14h-40m-10s-Clusters
# Coloring solver time: 0.0058 secs
# Total time 0.234 secs
# /home/rivas/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# percentil 0.5238368258424289
#
# **********************************************
# Parameters:
# Nodes file name: clusteringMeasures/RotatE/ClinicalRecord.txt
# Matrix file name: clusteringMeasures/RotatE/matrix_ClinicalRecord.tsv
# Threshold: 0.524
# ************************************************
#
# **** GO semEP-Node! ****
# Proccessing the vertex file clusteringMeasures/RotatE/ClinicalRecord.txt ...
# Number of nodes of the input file: 1242
# Time to build the graph to coloring: 0.0118 secs
# Graph to coloring - Num. of Nodes: 1242; Num. of Edges: 0
# Start coloring
# Average density of the partitions: 0.5473
# Number of partitions: 1
# Cluster directory: ClinicalRecord-0.5238-14h-40m-17s-Clusters
# Coloring solver time: 0.0059 secs
# Total time 0.238 secs
# /home/rivas/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# percentil 0.5459028280986116
#
# **********************************************
# Parameters:
# Nodes file name: clusteringMeasures/RotatE/ClinicalRecord.txt
# Matrix file name: clusteringMeasures/RotatE/matrix_ClinicalRecord.tsv
# Threshold: 0.546
# ************************************************
#
# **** GO semEP-Node! ****
# Proccessing the vertex file clusteringMeasures/RotatE/ClinicalRecord.txt ...
# Number of nodes of the input file: 1242
# Time to build the graph to coloring: 0.0165 secs
# Graph to coloring - Num. of Nodes: 1242; Num. of Edges: 0
# Start coloring
# Average density of the partitions: 0.5473
# Number of partitions: 1
# Cluster directory: ClinicalRecord-0.5459-14h-40m-24s-Clusters
# Coloring solver time: 0.0059 secs
# Total time 0.245 secs
# /home/rivas/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# percentil 0.5681401286155177
#
# **********************************************
# Parameters:
# Nodes file name: clusteringMeasures/RotatE/ClinicalRecord.txt
# Matrix file name: clusteringMeasures/RotatE/matrix_ClinicalRecord.tsv
# Threshold: 0.568
# ************************************************
#
# **** GO semEP-Node! ****
# Proccessing the vertex file clusteringMeasures/RotatE/ClinicalRecord.txt ...
# Number of nodes of the input file: 1242
# Time to build the graph to coloring: 0.0290 secs
# Graph to coloring - Num. of Nodes: 1242; Num. of Edges: 5
# Start coloring
# Average density of the partitions: 0.6068
# Number of partitions: 2
# Cluster directory: ClinicalRecord-0.5681-14h-40m-32s-Clusters
# Coloring solver time: 0.0072 secs
# Total time 0.270 secs
# ******************************************************************************
# METIS 5.0 Copyright 1998-13, Regents of the University of Minnesota
#  (HEAD: , Built on: May 17 2018, 14:13:21)
#  size of idx_t: 32bits, real_t: 32bits, idx_t *: 64bits
#
# Graph Information -----------------------------------------------------------
#  Name: metis.graph, #Vertices: 1242, #Edges: 770661, #Parts: 2
#
# Options ---------------------------------------------------------------------
#  ptype=kway, objtype=cut, ctype=shem, rtype=greedy, iptype=metisrb
#  dbglvl=0, ufactor=1.030, no2hop=NO, minconn=NO, contig=NO, nooutput=NO
#  seed=-1, niter=10, ncuts=1
#
# Direct k-way Partitioning ---------------------------------------------------
#  - Edgecut: -1038690746, communication volume: 1242.
#
#  - Balance:
#      constraint #0:  1.029 out of 0.002
#
#  - Most overweight partition:
#      pid: 0, actual: 639, desired: 621, ratio: 1.03.
#
#  - Subdomain connectivity: max: 0, min: 0, avg: 0.00
#
#  - Each partition is contiguous.
#
# Timing Information ----------------------------------------------------------
#   I/O:          		   0.156 sec
#   Partitioning: 		   0.027 sec   (METIS time)
#   Reporting:    		   0.015 sec
#
# Memory Information ----------------------------------------------------------
#   Max memory used:		  19.993 MB
# ******************************************************************************
# /home/rivas/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# percentil 0.5921311377109805
#
# **********************************************
# Parameters:
# Nodes file name: clusteringMeasures/RotatE/ClinicalRecord.txt
# Matrix file name: clusteringMeasures/RotatE/matrix_ClinicalRecord.tsv
# Threshold: 0.592
# ************************************************
#
# **** GO semEP-Node! ****
# Proccessing the vertex file clusteringMeasures/RotatE/ClinicalRecord.txt ...
# Number of nodes of the input file: 1242
# Time to build the graph to coloring: 0.0528 secs
# Graph to coloring - Num. of Nodes: 1242; Num. of Edges: 772
# Start coloring
# Average density of the partitions: 0.6015
# Number of partitions: 4
# Cluster directory: ClinicalRecord-0.5921-14h-40m-50s-Clusters
# Coloring solver time: 0.0080 secs
# Total time 0.281 secs
# ******************************************************************************
# METIS 5.0 Copyright 1998-13, Regents of the University of Minnesota
#  (HEAD: , Built on: May 17 2018, 14:13:21)
#  size of idx_t: 32bits, real_t: 32bits, idx_t *: 64bits
#
# Graph Information -----------------------------------------------------------
#  Name: metis.graph, #Vertices: 1242, #Edges: 770661, #Parts: 4
#
# Options ---------------------------------------------------------------------
#  ptype=kway, objtype=cut, ctype=shem, rtype=greedy, iptype=metisrb
#  dbglvl=0, ufactor=1.030, no2hop=NO, minconn=NO, contig=NO, nooutput=NO
#  seed=-1, niter=10, ncuts=1
#
# Direct k-way Partitioning ---------------------------------------------------
#  - Edgecut: 856215017, communication volume: 3726.
#
#  - Balance:
#      constraint #0:  1.027 out of 0.003
#
#  - Most overweight partition:
#      pid: 0, actual: 319, desired: 310, ratio: 1.03.
#
#  - Subdomain connectivity: max: 3, min: 3, avg: 3.00
#
#  - Each partition is contiguous.
#
# Timing Information ----------------------------------------------------------
#   I/O:          		   0.151 sec
#   Partitioning: 		   0.040 sec   (METIS time)
#   Reporting:    		   0.013 sec
#
# Memory Information ----------------------------------------------------------
#   Max memory used:		  16.887 MB
# ******************************************************************************
# /home/rivas/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# percentil 0.6204423134931116
#
# **********************************************
# Parameters:
# Nodes file name: clusteringMeasures/RotatE/ClinicalRecord.txt
# Matrix file name: clusteringMeasures/RotatE/matrix_ClinicalRecord.tsv
# Threshold: 0.620
# ************************************************
#
# **** GO semEP-Node! ****
# Proccessing the vertex file clusteringMeasures/RotatE/ClinicalRecord.txt ...
# Number of nodes of the input file: 1242
# Time to build the graph to coloring: 0.2087 secs
# Graph to coloring - Num. of Nodes: 1242; Num. of Edges: 20903
# Start coloring
# Average density of the partitions: 0.6053
# Number of partitions: 12
# Cluster directory: ClinicalRecord-0.6204-14h-41m-8s-Clusters
# Coloring solver time: 0.0105 secs
# Total time 0.442 secs
# ******************************************************************************
# METIS 5.0 Copyright 1998-13, Regents of the University of Minnesota
#  (HEAD: , Built on: May 17 2018, 14:13:21)
#  size of idx_t: 32bits, real_t: 32bits, idx_t *: 64bits
#
# Graph Information -----------------------------------------------------------
#  Name: metis.graph, #Vertices: 1242, #Edges: 770661, #Parts: 12
#
# Options ---------------------------------------------------------------------
#  ptype=kway, objtype=cut, ctype=shem, rtype=greedy, iptype=metisrb
#  dbglvl=0, ufactor=1.030, no2hop=NO, minconn=NO, contig=NO, nooutput=NO
#  seed=-1, niter=10, ncuts=1
#
# Direct k-way Partitioning ---------------------------------------------------
#  - Edgecut: -313901189, communication volume: 13662.
#
#  - Balance:
#      constraint #0:  1.024 out of 0.010
#
#  - Most overweight partition:
#      pid: 1, actual: 106, desired: 103, ratio: 1.02.
#
#  - Subdomain connectivity: max: 11, min: 11, avg: 11.00
#
#  - Each partition is contiguous.
#
# Timing Information ----------------------------------------------------------
#   I/O:          		   0.154 sec
#   Partitioning: 		   0.064 sec   (METIS time)
#   Reporting:    		   0.011 sec
#
# Memory Information ----------------------------------------------------------
#   Max memory used:		  19.823 MB
# ******************************************************************************
# /home/rivas/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /media/rivas/Data1/Projects/SymbolicLearning_KGE/PatternDetection/Utility.py:29: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=standard_similarity, x="similarity", shade=True, cut=0,
